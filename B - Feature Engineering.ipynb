# %% [markdown]
# # Feature Engineering for Demographic 'B'

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# ### Read in relevant data

# %%
Block = 'B'
df = pd.read_csv(r"C:\Users\gebruiker\Desktop\Thesis Scripts\Blocks\B\ACORN-B.csv", sep="\t")
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Unnamed: 0.1', axis=1, inplace=True)
df.drop('Acorn_grouped', axis=1, inplace=True)
# Out:
# c:\users\gebruiker\appdata\local\conda\conda\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Import weather data and drop Unnamed column
weather = pd.read_csv(r'C:\Users\gebruiker\Desktop\Thesis Scripts\Data\weather_engineered.csv', sep="\t")
weather.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Read in holiday data
holiday = pd.read_csv(r'C:\Users\gebruiker\Desktop\Thesis Scripts\Data\holiday.csv', sep='\t', encoding='utf-8')
holiday.drop('Unnamed: 0', axis=1, inplace=True)
# Subset relevant dates for the present dataset
holiday = holiday[((holiday.Month == 12) & (holiday.Year == 2012)) | (holiday.Year == 2013) | ((holiday.Month == 1) & (holiday.Year == 2014))]

# %% [markdown]
# ### Define Functions

# %%
def clean_and_weather(df):
    colnames = list(df.columns.values)
    df = df.values
    new_df = []
    for i in range(len(df)):
        if df[i][9] < 5:
            df[i][9] = 0
        elif df[i][9] >= 5:
            df[i][9] = 1
        if df[i][0] in Useful_IDs:
            new_df.append(df[i])
    df = pd.DataFrame(data=new_df, columns=colnames)
    return df

# %%
def Seasonality(df):
    # Initialize list for seasons data
    lst_seasons = []
    
    # Append season corresponding to Month number
    for i in range(len(df)):
        if df['Month'].values[i] in [1,2,12]:
            lst_seasons.append('Winter')
        elif df['Month'].values[i] in [3,4,5]:
            lst_seasons.append('Spring')
        elif df['Month'].values[i] in [6,7,8]:
            lst_seasons.append('Summer')
        elif df['Month'].values[i] in [9,10,11]:
            lst_seasons.append('Autumn')
    # Convert list to Pandas DF
    seasons = pd.DataFrame(lst_seasons)
    
    # Merge seasons to df and rename the seasons column to 'Seasons'
    df = pd.concat([df.reset_index(drop=True), seasons.reset_index(drop=True)], axis = 1)
    df.rename(columns={0: 'Season'}, inplace = True)
    
    return df

# %%
def zero_padding(test):
    list_hour = []
    for i in range(len(test)):
        x = str(test.iloc[i]).zfill(2)
        list_hour.append(x)
    return list_hour

# %%
def isHoliday(df, holiday):
    # Merge dataset while keeping the shape of the original dataset
    df = pd.merge(df, holiday, how='outer', on=['Year', 'Month', 'Day'])
    # Fill na's with 0's
    df.fillna(0, inplace=True)
    # Replace holidays with 1
    colnames = list(df.columns.values)
    df = df.values
    # Replace holidays with 1
    for i in range(len(df)):
        if len(str(df[i][23])) > 1:
            df[i][23] = 1

    df = pd.DataFrame(data=df, columns=colnames)
    # Rename column Type to isHoliday
    df.rename(columns={'Type': 'isHoliday'}, inplace = True)
    return df

# %% [markdown]
# ### Provide Summaries of data
#
# #### Tweak the Useful IDS. Now for prediction's sake it is set to very extreme values.

# %%
# Save distribution of MACIDs
ID_counts = df['LCLid'].value_counts() 
# Save the useful IDs relevant to out analysis
Useful_IDs = list(ID_counts[ID_counts >= (ID_counts.max()* 1)].index)
# Return the ratio of included to excluded Smart Meters
len(Useful_IDs)/len(ID_counts)
# Out:
# 0.2

# %%
df_c = clean_and_weather(df)
# Return the ratio of included observations from the original dataset
df_c.shape[0]/df.shape[0]
# Out:
# 0.20775366351326285

# %%
# Included smare meters
len(set(list(df_c['LCLid'])))
# Out:
# 5

# %%
# Save distribution of weekdays
weekday_counts = df_c['Weekday#'].value_counts() 

# The meters report data 99.7% of all the collection moments at a half-hourly level
weekdays = weekday_counts[0] / sum(weekday_counts)
print(weekdays / (5/7))
# Out:
# 1.0017857142857143

# %% [raw]
# # Save distribution of STD or ToU
# fee_type_counts = df_c['stdorToU'].value_counts()
#
# # Ratio of Standard tarrif vs Time-of-Use tarrifs == 74.6% vs 25.4%
# ToU = fee_type_counts[1] / sum(fee_type_counts)
# print(ToU)

# %% [markdown]
# ### Combine datasets - weather and holidays

# %%
df_c['Hour'][df_c['Minute'] == 30] += .5
# Out:
# c:\users\gebruiker\appdata\local\conda\conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# Merge df and weather data by 'Year', 'Month', 'Day', 'Hour'
new_df = pd.merge(df_c, weather, how='outer', on=['Year', 'Month', 'Day', 'Hour'])
df = new_df.iloc[:,0:23]

# Clear redundant data from memory
del new_df, weather, df_c

# %%
# Apply Seasonality function to df
df = Seasonality(df)

# %%
df.columns
# Out:
# Index(['LCLid', 'stdorToU', 'KWH/hh (per half hour) ', 'Acorn', 'Year',
#        'Month', 'Day', 'Hour', 'Minute', 'Weekday#', 'apparentTemperature',
#        'cloudCover', 'dewPoint', 'humidity', 'pressure', 'temperature',
#        'visibility', 'windBearing', 'windSpeed', 'Season'],
#       dtype='object')

# %%
# Create dummies for seasons and binary for Standard or Time-of-Use
df = pd.get_dummies(df, columns=['Season', 'stdorToU'])
df.rename(columns={'stdorToU_Std': 'StdorToU'}, inplace=True)

# %%
# Confirm what dates are included
holiday
# Out:
#                       Type  Year  Month  Day
# 0               Boxing Day  2012     12   26
# 1            Christmas Day  2012     12   25
# 9               Boxing Day  2013     12   26
# 10           Christmas Day  2013     12   25
# 11     Summer bank holiday  2013      8   26
# 12     Spring bank holiday  2013      5   27
# 13  Early May bank holiday  2013      6    5
# 14           Easter Monday  2013      1    4
# 15             Good Friday  2013      3   29
# 16          New Year?s Day  2013      1    1
# 24          New Year?s Day  2014      1    1

# %%
# Merge holiday data into isHoliday column. 1 for is holiday, 0 else.
df = isHoliday(df, holiday)

# %% [markdown]
# # Remove wrong data inputs for KWH/halfh

# %%
df.rename(columns={'KWH/hh (per half hour) ': 'KWH_hh'}, inplace=True)
df['KWH_hh'] = pd.to_numeric(df['KWH_hh'], errors='coerce').fillna(-100)
len(set(list(df["LCLid"])))
# Out:
# 6

# %%
df[df['KWH_hh'] == -100]
len(set(list(df['LCLid'][df['KWH_hh'] == -100])))
# Out:
# 5

# %%
# Remove fucked up observations
df = df[df['KWH_hh'] != -100]
#df = df[df['KWH/halfh'] != "Null"]

# %% [markdown]
# ### Add Date columns

# %%
def datetime_to_string(df):
    vals = df.values
    print(df.columns)
    # Convert column values to integers (rounds numbers down) e.g 0.9 -> 0
    vals[:,2] = [int(vals[i,3]) for i in range(len(vals[:]))]
    vals[:,3] = [int(vals[i,4]) for i in range(len(vals[:]))]
    vals[:,4] = [int(vals[i,5]) for i in range(len(vals[:]))]
    vals[:,5] = [int(vals[i,6]) for i in range(len(vals[:]))]
    vals[:,6] = [int(vals[i,7]) for i in range(len(vals[:]))]
    
    datetime = ['{:%Y-%m-%d %H:%M}'.format(dt.datetime(vals[i,2],vals[i,3],vals[i,4],
                                                       vals[i,5],vals[i,6])) for i in range(len(vals[:]))]
    df['DateTime'] = datetime
    return df

# %%
df = datetime_to_string(df)
# Out:
# Index(['LCLid', 'KWH_hh', 'Acorn', 'Year', 'Month', 'Day', 'Hour', 'Minute',
#        'Weekday#', 'apparentTemperature', 'cloudCover', 'dewPoint', 'humidity',
#        'pressure', 'temperature', 'visibility', 'windBearing', 'windSpeed',
#        'Season_Autumn', 'Season_Spring', 'Season_Summer', 'Season_Winter',
#        'StdorToU', 'isHoliday'],
#       dtype='object')

# %% [markdown]
# ### Create time categories

# %%
# Initialize column with value None
df['TimePeriod'] = 'Peak'
# Implement categories for Time period of the day
df['TimePeriod'][(df['Hour'] >= 8) & (df['Hour'] < 16)] = 'Off-peak'
df['TimePeriod'][(df['Hour'] >= 0) & (df['Hour'] < 8)] = 'Night'
# Out:
# c:\users\gebruiker\appdata\local\conda\conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# c:\users\gebruiker\appdata\local\conda\conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
len(set(list(df['Hour'][df['TimePeriod']=='Morning'])))
# Out:
# 0

# %%
len(set(list(df['Hour'][df['TimePeriod']=='Evening'])))
# Out:
# 0

# %%
len(set(list(df['Hour'][df['TimePeriod']=='Night'])))
# Out:
# 16

# %%
# Create dummy variable for Morning, Evening, Night
df = pd.get_dummies(df, columns=['TimePeriod'])

# %%
df.columns
# Out:
# Index(['LCLid', 'KWH_hh', 'Acorn', 'Year', 'Month', 'Day', 'Hour', 'Minute',
#        'Weekday#', 'apparentTemperature', 'cloudCover', 'dewPoint', 'humidity',
#        'pressure', 'temperature', 'visibility', 'windBearing', 'windSpeed',
#        'Season_Autumn', 'Season_Spring', 'Season_Summer', 'Season_Winter',
#        'StdorToU', 'isHoliday', 'DateTime', 'TimePeriod_Night',
#        'TimePeriod_Off-peak', 'TimePeriod_Peak'],
#       dtype='object')

# %% [markdown]
# ### Final touch-ups

# %%
# Rename columns for nicer names
df.rename(columns={'stdorToU_ToU': 'StdorToU', 'Weekday#': 'isWeekend',
                   'TimePeriod_Peak': 'isPeak','TimePeriod_Off-peak': 'isOff_Peak',
                   'TimePeriod_Night': 'isNight', 'Season_Autumn': 'isAutumn', 'Season_Spring': 'isSpring',
                   'Season_Summer': 'isSummer', 'Season_Winter': 'isWinter'
                  }, inplace=True)

# %%
# Change is weekend values from float to integer
df['isWeekend'] = df['isWeekend'].astype(int)

# %%
# Change order of columns
cols = ['LCLid', 'Acorn', 'Year', 'Month', 'Day', 'Hour', 'DateTime',
       'apparentTemperature', 'cloudCover', 'dewPoint', 'humidity', 'pressure',
       'temperature', 'visibility', 'windBearing', 'windSpeed', 'StdorToU', 'isAutumn',
       'isSpring', 'isSummer', 'isWinter', 'isHoliday',
       'isPeak', 'isOff_Peak', 'isNight', 'isWeekend', 'KWH_hh']
df = df[cols]

# %%
df.head()
# Out:
#        LCLid    Acorn  Year Month Day Hour          DateTime  \
# 0  MAC001966  ACORN-B  2012    11   1    0  2012-11-01 00:00
# 1  MAC003355  ACORN-B  2012    11   1    0  2012-11-01 00:00
# 2  MAC003445  ACORN-B  2012    11   1    0  2012-11-01 00:00
# 3  MAC003876  ACORN-B  2012    11   1    0  2012-11-01 00:00
# 4  MAC004567  ACORN-B  2012    11   1    0  2012-11-01 00:00
#
#   apparentTemperature cloudCover dewPoint  ...   isAutumn isSpring isSummer  \
# 0             11.1933      0.602    46.82  ...          1        0        0
# 1             11.1933      0.602    46.82  ...          1        0        0
# 2             11.1933      0.602    46.82  ...          1        0        0
# 3             11.1933      0.602    46.82  ...          1        0        0
# 4             11.1933      0.602    46.82  ...          1        0        0
#
#   isWinter isHoliday isPeak isOff_Peak isNight isWeekend KWH_hh
# 0        0         0      0          0       1         0  0.162
# 1        0         0      0          0       1         0  0.248
# 2        0         0      0          0       1         0  0.507
# 3        0         0      0          0       1         0  0.139
# 4        0         0      0          0       1         0  0.054
#
# [5 rows x 27 columns]

# %%
# View subset of data
df[df['LCLid'] == 'MAC001966']
# Out:
#             LCLid    Acorn  Year Month Day  Hour          DateTime  \
# 0       MAC001966  ACORN-B  2012    11   1     0  2012-11-01 00:00
# 5       MAC001966  ACORN-B  2012    11   1   0.5  2012-11-01 00:30
# 10      MAC001966  ACORN-B  2012    11   1     1  2012-11-01 01:00
# 15      MAC001966  ACORN-B  2012    11   1   1.5  2012-11-01 01:30
# 20      MAC001966  ACORN-B  2012    11   1     2  2012-11-01 02:00
# 25      MAC001966  ACORN-B  2012    11   1   2.5  2012-11-01 02:30
# 30      MAC001966  ACORN-B  2012    11   1     3  2012-11-01 03:00
# 35      MAC001966  ACORN-B  2012    11   1   3.5  2012-11-01 03:30
# 40      MAC001966  ACORN-B  2012    11   1     4  2012-11-01 04:00
# 45      MAC001966  ACORN-B  2012    11   1   4.5  2012-11-01 04:30
# 50      MAC001966  ACORN-B  2012    11   1     5  2012-11-01 05:00
# 55      MAC001966  ACORN-B  2012    11   1   5.5  2012-11-01 05:30
# 60      MAC001966  ACORN-B  2012    11   1     6  2012-11-01 06:00
# 65      MAC001966  ACORN-B  2012    11   1   6.5  2012-11-01 06:30
# 70      MAC001966  ACORN-B  2012    11   1     7  2012-11-01 07:00
# 75      MAC001966  ACORN-B  2012    11   1   7.5  2012-11-01 07:30
# 80      MAC001966  ACORN-B  2012    11   1     8  2012-11-01 08:00
# 85      MAC001966  ACORN-B  2012    11   1   8.5  2012-11-01 08:30
# 90      MAC001966  ACORN-B  2012    11   1     9  2012-11-01 09:00
# 95      MAC001966  ACORN-B  2012    11   1   9.5  2012-11-01 09:30
# 100     MAC001966  ACORN-B  2012    11   1    10  2012-11-01 10:00
# 105     MAC001966  ACORN-B  2012    11   1  10.5  2012-11-01 10:30
# 110     MAC001966  ACORN-B  2012    11   1    11  2012-11-01 11:00
# 115     MAC001966  ACORN-B  2012    11   1  11.5  2012-11-01 11:30
# 120     MAC001966  ACORN-B  2012    11   1    12  2012-11-01 12:00
# 125     MAC001966  ACORN-B  2012    11   1  12.5  2012-11-01 12:30
# 130     MAC001966  ACORN-B  2012    11   1    13  2012-11-01 13:00
# 135     MAC001966  ACORN-B  2012    11   1  13.5  2012-11-01 13:30
# 140     MAC001966  ACORN-B  2012    11   1    14  2012-11-01 14:00
# 145     MAC001966  ACORN-B  2012    11   1  14.5  2012-11-01 14:30
# ...           ...      ...   ...   ...  ..   ...               ...
# 109610  MAC001966  ACORN-B  2014     1  31     9  2014-01-31 09:00
# 109615  MAC001966  ACORN-B  2014     1  31   9.5  2014-01-31 09:30
# 109620  MAC001966  ACORN-B  2014     1  31    10  2014-01-31 10:00
# 109625  MAC001966  ACORN-B  2014     1  31  10.5  2014-01-31 10:30
# 109630  MAC001966  ACORN-B  2014     1  31    11  2014-01-31 11:00
# 109635  MAC001966  ACORN-B  2014     1  31  11.5  2014-01-31 11:30
# 109640  MAC001966  ACORN-B  2014     1  31    12  2014-01-31 12:00
# 109645  MAC001966  ACORN-B  2014     1  31  12.5  2014-01-31 12:30
# 109650  MAC001966  ACORN-B  2014     1  31    13  2014-01-31 13:00
# 109655  MAC001966  ACORN-B  2014     1  31  13.5  2014-01-31 13:30
# 109660  MAC001966  ACORN-B  2014     1  31    14  2014-01-31 14:00
# 109665  MAC001966  ACORN-B  2014     1  31  14.5  2014-01-31 14:30
# 109670  MAC001966  ACORN-B  2014     1  31    15  2014-01-31 15:00
# 109675  MAC001966  ACORN-B  2014     1  31  15.5  2014-01-31 15:30
# 109680  MAC001966  ACORN-B  2014     1  31    16  2014-01-31 16:00
# 109685  MAC001966  ACORN-B  2014     1  31  16.5  2014-01-31 16:30
# 109690  MAC001966  ACORN-B  2014     1  31    17  2014-01-31 17:00
# 109695  MAC001966  ACORN-B  2014     1  31  17.5  2014-01-31 17:30
# 109700  MAC001966  ACORN-B  2014     1  31    18  2014-01-31 18:00
# 109705  MAC001966  ACORN-B  2014     1  31  18.5  2014-01-31 18:30
# 109710  MAC001966  ACORN-B  2014     1  31    19  2014-01-31 19:00
# 109715  MAC001966  ACORN-B  2014     1  31  19.5  2014-01-31 19:30
# 109720  MAC001966  ACORN-B  2014     1  31    20  2014-01-31 20:00
# 109725  MAC001966  ACORN-B  2014     1  31  20.5  2014-01-31 20:30
# 109730  MAC001966  ACORN-B  2014     1  31    21  2014-01-31 21:00
# 109735  MAC001966  ACORN-B  2014     1  31  21.5  2014-01-31 21:30
# 109740  MAC001966  ACORN-B  2014     1  31    22  2014-01-31 22:00
# 109745  MAC001966  ACORN-B  2014     1  31  22.5  2014-01-31 22:30
# 109750  MAC001966  ACORN-B  2014     1  31    23  2014-01-31 23:00
# 109755  MAC001966  ACORN-B  2014     1  31  23.5  2014-01-31 23:30
#
#        apparentTemperature cloudCover dewPoint  ...   isAutumn isSpring  \
# 0                  11.1933      0.602    46.82  ...          1        0
# 5                  10.1794      0.677   47.043  ...          1        0
# 10                 9.16556      0.752   47.266  ...          1        0
# 15                 7.54278      0.754   46.453  ...          1        0
# 20                    5.92      0.756    45.64  ...          1        0
# 25                 5.84778      0.758   45.402  ...          1        0
# 30                 5.77556       0.76   45.164  ...          1        0
# 35                 5.70167      0.674   44.355  ...          1        0
# 40                 5.62778      0.588   43.546  ...          1        0
# 45                 5.56944      0.552   43.552  ...          1        0
# 50                 5.51111      0.516   43.558  ...          1        0
# 55                 5.17444      0.668   43.235  ...          1        0
# 60                 4.83778       0.82   42.912  ...          1        0
# 65                 4.78778      0.641   42.675  ...          1        0
# 70                 4.73778      0.462   42.438  ...          1        0
# 75                    4.32      0.475   42.333  ...          1        0
# 80                 3.90222      0.488   42.228  ...          1        0
# 85                 4.25056      0.424   42.234  ...          1        0
# 90                 4.59889       0.36    42.24  ...          1        0
# 95                 4.58778      0.402   41.901  ...          1        0
# 100                4.57667      0.444   41.562  ...          1        0
# 105                4.98889      0.433   41.177  ...          1        0
# 110                5.40111      0.422   40.792  ...          1        0
# 115                5.59778      0.431   40.325  ...          1        0
# 120                5.79444       0.44   39.858  ...          1        0
# 125                5.41556      0.399   40.116  ...          1        0
# 130                5.03667      0.358   40.374  ...          1        0
# 135                4.84111      0.368   40.086  ...          1        0
# 140                4.64556      0.378   39.798  ...          1        0
# 145                4.46722      0.407   39.238  ...          1        0
# ...                    ...        ...      ...  ...        ...      ...
# 109610             1.33556      0.536     38.2  ...          0        0
# 109615             1.74833      0.768   38.941  ...          0        0
# 109620             2.16111          1   39.682  ...          0        0
# 109625             2.33611          1   39.493  ...          0        0
# 109630             2.51111          1   39.304  ...          0        0
# 109635             2.51167          1    39.12  ...          0        0
# 109640             2.51222          1   38.936  ...          0        0
# 109645             2.57667          1    38.58  ...          0        0
# 109650             2.64111          1   38.224  ...          0        0
# 109655             2.49611          1   38.713  ...          0        0
# 109660             2.35111          1   39.202  ...          0        0
# 109665             2.27222          1   39.414  ...          0        0
# 109670             2.19333          1   39.626  ...          0        0
# 109675             1.98722          1   39.806  ...          0        0
# 109680             1.78111          1   39.986  ...          0        0
# 109685               1.785          1   40.157  ...          0        0
# 109690             1.78889          1   40.328  ...          0        0
# 109695             2.07111          1    40.92  ...          0        0
# 109700             2.35333          1   41.512  ...          0        0
# 109705             2.50111          1   41.624  ...          0        0
# 109710             2.64889          1   41.736  ...          0        0
# 109715             2.84944          1   42.307  ...          0        0
# 109720                3.05          1   42.878  ...          0        0
# 109725             3.17444          1   43.395  ...          0        0
# 109730             3.29889          1   43.912  ...          0        0
# 109735             3.89556          1   44.458  ...          0        0
# 109740             4.49222          1   45.004  ...          0        0
# 109745             4.87222          1   45.398  ...          0        0
# 109750             5.25222          1   45.792  ...          0        0
# 109755             5.52611          0   46.129  ...          0        0
#
#        isSummer isWinter isHoliday isPeak isOff_Peak isNight isWeekend KWH_hh
# 0             0        0         0      0          0       1         0  0.162
# 5             0        0         0      0          0       1         0  0.111
# 10            0        0         0      0          0       1         0  0.115
# 15            0        0         0      0          0       1         0  0.109
# 20            0        0         0      0          0       1         0  0.145
# 25            0        0         0      0          0       1         0  0.166
# 30            0        0         0      0          0       1         0  0.151
# 35            0        0         0      0          0       1         0  0.150
# 40            0        0         0      0          0       1         0  0.104
# 45            0        0         0      0          0       1         0  0.113
# 50            0        0         0      0          0       1         0  0.195
# 55            0        0         0      0          0       1         0  0.654
# 60            0        0         0      0          0       1         0  0.614
# 65            0        0         0      0          0       1         0  0.296
# 70            0        0         0      0          0       1         0  0.161
# 75            0        0         0      0          0       1         0  0.229
# 80            0        0         0      0          1       0         0  0.356
# 85            0        0         0      0          1       0         0  0.340
# 90            0        0         0      0          1       0         0  0.425
# 95            0        0         0      0          1       0         0  0.756
# 100           0        0         0      0          1       0         0  1.002
# 105           0        0         0      0          1       0         0  0.412
# 110           0        0         0      0          1       0         0  0.989
# 115           0        0         0      0          1       0         0  0.448
# 120           0        0         0      0          1       0         0  0.386
# 125           0        0         0      0          1       0         0  0.776
# 130           0        0         0      0          1       0         0  0.197
# 135           0        0         0      0          1       0         0  0.147
# 140           0        0         0      0          1       0         0  0.158
# 145           0        0         0      0          1       0         0  0.484
# ...         ...      ...       ...    ...        ...     ...       ...    ...
# 109610        0        1         0      0          1       0         0  0.134
# 109615        0        1         0      0          1       0         0  0.075
# 109620        0        1         0      0          1       0         0  0.080
# 109625        0        1         0      0          1       0         0  0.138
# 109630        0        1         0      0          1       0         0  0.099
# 109635        0        1         0      0          1       0         0  0.141
# 109640        0        1         0      0          1       0         0  0.166
# 109645        0        1         0      0          1       0         0  0.075
# 109650        0        1         0      0          1       0         0  0.192
# 109655        0        1         0      0          1       0         0  0.722
# 109660        0        1         0      0          1       0         0  0.555
# 109665        0        1         0      0          1       0         0  0.411
# 109670        0        1         0      0          1       0         0  0.248
# 109675        0        1         0      0          1       0         0  0.193
# 109680        0        1         0      1          0       0         0  0.201
# 109685        0        1         0      1          0       0         0  0.184
# 109690        0        1         0      1          0       0         0  0.216
# 109695        0        1         0      1          0       0         0  0.259
# 109700        0        1         0      1          0       0         0  0.321
# 109705        0        1         0      1          0       0         0  0.597
# 109710        0        1         0      1          0       0         0  0.216
# 109715        0        1         0      1          0       0         0  0.141
# 109720        0        1         0      1          0       0         0  0.136
# 109725        0        1         0      1          0       0         0  0.526
# 109730        0        1         0      1          0       0         0  0.745
# 109735        0        1         0      1          0       0         0  0.647
# 109740        0        1         0      1          0       0         0  0.636
# 109745        0        1         0      1          0       0         0  0.660
# 109750        0        1         0      1          0       0         0  0.660
# 109755        0        1         0      1          0       0         0  0.454
#
# [21951 rows x 27 columns]

# %% [markdown]
# ### Save data to csv for modelling

# %%
# Save df to working directory
df.to_csv('Feat_Eng_'+Block+'.csv', sep='\t', encoding='utf-8')
